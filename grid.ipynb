# %%
import pandas as pd
import plotly.graph_objects as go

import gridstatusio

gridstatusio.__version__
# Out:
# '0.10.0'

# %%
from gridstatusio import GridStatusClient

# %%
client = GridStatusClient(api_key="0438e7b9f460415a865fe6893e334442")

# %%
client.list_datasets(filter_term="CAISO LMP")
# Out:
# +-------------------------------+------------------------------------------------------------------------------------------------------+
# |              Key              |                                                Value                                                 |
# +-------------------------------+------------------------------------------------------------------------------------------------------+
# |             Name              |                                      CAISO LMP Day Ahead Hourly                                      |
# |              ID               |                                      caiso_lmp_day_ahead_hourly                                      |
# |          Description          |                                        Day Ahead Hourly LMPs                                         |
# | Earliest available time (UTC) |                                      2019-03-21T07:00:00+00:00                                       |
# ...

# %%
QUERY_LIMIT = 50

# %%
help(client)
# Out:
# Help on GridStatusClient in module gridstatusio.gs_client object:
#
# class GridStatusClient(builtins.object)
#  |  GridStatusClient(api_key=None, host='https://api.gridstatus.io/v1', request_format='json', max_retries=3)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, api_key=None, host='https://api.gridstatus.io/v1', request_format='json', max_retries=3)
#  |      Create a GridStatus.io API client
#  |
#  |      Parameters:
#  |          api_key (str): The API key to use for authentication.
#  |          If not provided, the GRIDSTATUS_API_KEY environment variable will be used.
#  |
#  |          host (str): The host to use for the API.
#  |              Defaults to https://api.gridstatus.io
#  |
#  |          request_format (str): The format to use for requests. Options are "json"
#  |              or "csv". Defaults to "json".
#  |
#  |          max_retries (int): The maximum number of retries to attempt if an API rate
# ...

# %%
import warnings

warnings.filterwarnings("ignore")

price_df = client.get_dataset(
    dataset="caiso_lmp_day_ahead_hourly",
    start="2024-02-10",  # start from beginning of data
    end="2024-02-11",  # end at most recent data,
    filter_column="location",
    filter_value="RAINBOW_1_N001",
    # filter_value="NSP.S_RIDGE1",
    limit=50,
)
# Out:
# Fetching Page 1...Done in 0.33 seconds.
# Total rows: 24/50 (48.0% of limit)
#
# Total number of rows: 24

# %%
price_df
# Out:
#           interval_start_utc          interval_end_utc            market  \
# 0  2024-02-05 00:00:00+00:00 2024-02-05 01:00:00+00:00  DAY_AHEAD_HOURLY
# 1  2024-02-05 01:00:00+00:00 2024-02-05 02:00:00+00:00  DAY_AHEAD_HOURLY
# 2  2024-02-05 02:00:00+00:00 2024-02-05 03:00:00+00:00  DAY_AHEAD_HOURLY
# 3  2024-02-05 03:00:00+00:00 2024-02-05 04:00:00+00:00  DAY_AHEAD_HOURLY
# 4  2024-02-05 04:00:00+00:00 2024-02-05 05:00:00+00:00  DAY_AHEAD_HOURLY
# 5  2024-02-05 05:00:00+00:00 2024-02-05 06:00:00+00:00  DAY_AHEAD_HOURLY
# 6  2024-02-05 06:00:00+00:00 2024-02-05 07:00:00+00:00  DAY_AHEAD_HOURLY
# 7  2024-02-05 07:00:00+00:00 2024-02-05 08:00:00+00:00  DAY_AHEAD_HOURLY
# 8  2024-02-05 08:00:00+00:00 2024-02-05 09:00:00+00:00  DAY_AHEAD_HOURLY
# 9  2024-02-05 09:00:00+00:00 2024-02-05 10:00:00+00:00  DAY_AHEAD_HOURLY
# 10 2024-02-05 10:00:00+00:00 2024-02-05 11:00:00+00:00  DAY_AHEAD_HOURLY
# 11 2024-02-05 11:00:00+00:00 2024-02-05 12:00:00+00:00  DAY_AHEAD_HOURLY
# ...

# %%
# To register, use the code below. Please note that for these code examples we are using filler values for username
# (freddo), password (the_frog), email (freddo@frog.org), org (freds world) and you should replace each if you are
# copying and pasting this code.

import requests
register_url = 'https://api.watttime.org/register'
params = {'username': 'AAAK',
         'password': 'Pelikan99@',
         'email': 'aghaa001@umn.edu'}
rsp = requests.post(register_url, json=params)
print(rsp.text)
# Out:
# {"error":"Failed to create user"}

# %%
# To login and obtain an access token, use this code:

import requests
from requests.auth import HTTPBasicAuth
login_url = 'https://api.watttime.org/login'
rsp = requests.get(login_url, auth=HTTPBasicAuth('AAAK', 'Pelikan99@'))
TOKEN = rsp.json()['token']
print(rsp.json())
# Out:
# {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6ImJhc2ljIiwiaWF0IjoxNzQ2MDI4NjM0LCJleHAiOjE3NDYwMzA0MzQsImlzcyI6IldhdHRUaW1lIiwic3ViIjoiQUFBSyJ9.BydfcbLa7mGjfhmLYzSeUicy7St9Nsi_CV8ABq8xieZF5-wrlTutrjao0GMFeAAM0VhQtS0O7rsxolBpMe1-eTwGyA0Ag0f-IDl9jicPDKUOYRga-9AJwjuwuA8kG6iqehgBrs_QCbTkCIy7J3n4pFBVGTWDXJiQI0I5UabTLCFCPXKqgMa26O8B_cp3PHK-EkgxbY7WVz7-zQmZISzX5OhA7Eo1VLizyz-zqfIXJjaMnf_3MaR1ZOIXl-vfzYum-dhsbYBNdu7EVdXuzE-Hy3FA_cb0BV_QizYUYUnZ9GBygB4GCgzs-FB5V0DlYsu4uYh6HI7WRPPZuztBVhq7rg'}

# %%
import requests

url = "https://api.watttime.org/v3/my-access"

# Provide your TOKEN here, see https://docs.watttime.org/#tag/Authentication/operation/get_token_login_get for more information
headers = {"Authorization": f"Bearer {TOKEN}"}
params = {}
response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
print(response.json())
# Out:
# {'signal_types': [{'signal_type': 'co2_moer', 'regions': [{'region': 'CAISO_NORTH', 'region_full_name': 'California ISO Northern', 'parent': 'CAISO', 'data_point_period_seconds': 300, 'endpoints': [{'endpoint': 'v3/historical', 'models': [{'model': '2022-10-01', 'data_start': '2020-01-01', 'data_end': '2024-12-04', 'train_start': '2020-03-01', 'train_end': '2022-03-01', 'type': 'binned_regression'}, {'model': '2023-03-01', 'data_start': '2020-03-01', 'data_end': None, 'train_start': '2021-01-01', 'train_end': '2023-03-01', 'type': 'binned_regression'}]}, {'endpoint': 'v3/forecast', 'models': [{'model': '2022-10-01', 'data_start': '2024-08-20', 'data_end': '2024-11-20', 'train_start': '2020-01-01', 'train_end': '2021-12-31', 'historical_model': '2022-10-01'}, {'model': '2023-03-01', 'data_start': '2024-08-20', 'data_end': None, 'train_start': '2021-01-01', 'train_end': '2023-01-01', 'historical_model': '2023-03-01'}]}]}]}, {'signal_type': 'health_damage', 'regions': [{'region': 'CAISO
# ...

# %%
import requests

url = "https://api.watttime.org/v3/region-from-loc"

# Provide your TOKEN here, see https://docs.watttime.org/#tag/Authentication/operation/get_token_login_get for more information
headers = {"Authorization": f"Bearer {TOKEN}"}
params = {"latitude": "36.778261", "longitude": "-119.417932", "signal_type": "co2_moer"}
response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
print(response.json())
# Out:
# {'region': 'CAISO_NORTH', 'region_full_name': 'California ISO Northern', 'signal_type': 'co2_moer'}

# %%
import requests

url = "https://api.watttime.org/v3/my-access"


headers = {"Authorization": f"Bearer {TOKEN}"}
params = {}
response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
print(response.json())
# Out:
# {'signal_types': [{'signal_type': 'co2_moer', 'regions': [{'region': 'CAISO_NORTH', 'region_full_name': 'California ISO Northern', 'parent': 'CAISO', 'data_point_period_seconds': 300, 'endpoints': [{'endpoint': 'v3/historical', 'models': [{'model': '2022-10-01', 'data_start': '2020-01-01', 'data_end': '2024-12-04', 'train_start': '2020-03-01', 'train_end': '2022-03-01', 'type': 'binned_regression'}, {'model': '2023-03-01', 'data_start': '2020-03-01', 'data_end': None, 'train_start': '2021-01-01', 'train_end': '2023-03-01', 'type': 'binned_regression'}]}, {'endpoint': 'v3/forecast', 'models': [{'model': '2022-10-01', 'data_start': '2024-08-20', 'data_end': '2024-11-20', 'train_start': '2020-01-01', 'train_end': '2021-12-31', 'historical_model': '2022-10-01'}, {'model': '2023-03-01', 'data_start': '2024-08-20', 'data_end': None, 'train_start': '2021-01-01', 'train_end': '2023-01-01', 'historical_model': '2023-03-01'}]}]}]}, {'signal_type': 'health_damage', 'regions': [{'region': 'CAISO
# ...

# %%
url = "https://api.watttime.org/v3/historical"


headers = {"Authorization": f"Bearer {TOKEN}"}
params = {
    "region": "CAISO_NORTH",
    "start": "2024-02-09T00:00:00-0800",
    "end": "2024-02-11T00:00:00-0800",
    "signal_type": "co2_moer",
}
response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
print(response.json())
# Out:
# {'data': [{'point_time': '2024-02-04T08:00:00+00:00', 'value': 946.0}, {'point_time': '2024-02-04T08:05:00+00:00', 'value': 947.0}, {'point_time': '2024-02-04T08:10:00+00:00', 'value': 947.0}, {'point_time': '2024-02-04T08:15:00+00:00', 'value': 946.0}, {'point_time': '2024-02-04T08:20:00+00:00', 'value': 945.0}, {'point_time': '2024-02-04T08:25:00+00:00', 'value': 946.0}, {'point_time': '2024-02-04T08:30:00+00:00', 'value': 946.0}, {'point_time': '2024-02-04T08:35:00+00:00', 'value': 946.0}, {'point_time': '2024-02-04T08:40:00+00:00', 'value': 946.0}, {'point_time': '2024-02-04T08:45:00+00:00', 'value': 945.0}, {'point_time': '2024-02-04T08:50:00+00:00', 'value': 944.0}, {'point_time': '2024-02-04T08:55:00+00:00', 'value': 944.0}, {'point_time': '2024-02-04T09:00:00+00:00', 'value': 940.0}, {'point_time': '2024-02-04T09:05:00+00:00', 'value': 943.0}, {'point_time': '2024-02-04T09:10:00+00:00', 'value': 943.0}, {'point_time': '2024-02-04T09:15:00+00:00', 'value': 944.0}, {'point_time
# ...

# %%
r = response.json()

df = pd.DataFrame(r['data'])
df
# Out:
#                     point_time  value
# 0    2024-02-04T08:00:00+00:00  946.0
# 1    2024-02-04T08:05:00+00:00  947.0
# 2    2024-02-04T08:10:00+00:00  947.0
# 3    2024-02-04T08:15:00+00:00  946.0
# 4    2024-02-04T08:20:00+00:00  945.0
# ..                         ...    ...
# 572  2024-02-06T07:40:00+00:00  984.0
# 573  2024-02-06T07:45:00+00:00  983.0
# 574  2024-02-06T07:50:00+00:00  982.0
# 575  2024-02-06T07:55:00+00:00  983.0
# 576  2024-02-06T08:00:00+00:00  972.0
#
# [577 rows x 2 columns]

# %%
hour_list = [hour for hour in range(24) for _ in range(12)]

# %%
price_emissions_df = pd.DataFrame()
emission_data = response.json()['data']
emission_df = pd.DataFrame(emission_data)
end_id = emission_df.loc[emission_df['point_time']=='2024-02-09T00:00:00+00:00'].index.to_list()[0]
start_id = emission_df.loc[emission_df['point_time']=='2024-02-11T00:00:00+00:00'].index.to_list()[0]
emission_df = emission_df[end_id:start_id]
emission_data = emission_df['value']
emission_df[start_id:end_id]


price_emissions_df['hour'] = hour_list
repeated_prices = price_df['lmp'].repeat(12).reset_index(drop=True)

price_emissions_df['price'] = price_df['lmp'].repeat(12).reset_index(drop=True)
price_emissions_df['emissions'] = emission_df['value'].values

price_emissions_df.to_csv('2023-01-05.csv')
